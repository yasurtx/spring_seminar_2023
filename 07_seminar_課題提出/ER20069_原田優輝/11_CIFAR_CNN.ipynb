# %% [markdown]
# <a href="https://colab.research.google.com/github/yukiharada1228/spring_seminar_2023/blob/main/07_seminar_%E8%AA%B2%E9%A1%8C%E6%8F%90%E5%87%BA/ER20069_%E5%8E%9F%E7%94%B0%E5%84%AA%E8%BC%9D/11_CIFAR_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 5.7 MB/s eta 0:00:00

# %%
import torch
from torch import nn

import torchvision
from torchvision import transforms

import optuna

# %%
train_data = torchvision.datasets.CIFAR10(
    root="./", train=True, transform=transforms.ToTensor(), download=True)
test_data = torchvision.datasets.CIFAR10(
    root="./", train=False, transform=transforms.ToTensor(), download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./
# Files already downloaded and verified

# %%
def train(model, device, train_loader, criterion, optimizer):
    sum_loss = 0
    num_correct = 0
    num_images = len(train_loader.dataset)
    model.train()
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        model.zero_grad()
        loss.backward()
        optimizer.step()

        sum_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        num_correct += torch.sum(preds == labels).item()
    mean_loss = sum_loss / num_images
    accuracy = num_correct / num_images
    print({
        "action": "train", 
        "mean_loss": mean_loss, 
        "accuracy": accuracy}
    )
    return mean_loss, accuracy

def test(model, device, test_loader):
    num_correct = 0
    num_images = len(test_loader.dataset)
    model.eval()
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)

        preds = torch.argmax(outputs, dim=1)
        num_correct += torch.sum(preds == labels).item()
    accuracy = num_correct / num_images
    print({
        "action": "test", 
        "accuracy": accuracy}
    )
    return accuracy

def get_activation(trial):
    activation_names = ('ReLU', 'ELU')
    activation_name = trial.suggest_categorical('activation', activation_names)
    if activation_name == activation_names[0]:
        activation = nn.ReLU()
    else:
        activation = nn.ELU()
    return activation, activation_name

class CNN(nn.Module):
    def __init__(self, activation, fc_units, num_layer):
        super(CNN, self).__init__()
        in_height = 32
        in_width = 32
        in_channels = 3
        out_channels = 16
        self.convs = nn.ModuleList([
            nn.Conv2d(
                in_channels, out_channels, kernel_size=3, stride=1, padding=1)])
        out_height = in_height
        out_width = in_width
        for i in range(1, num_layer - 3):
            out_height //= 2
            out_width //= 2
            in_channels = out_channels
            out_channels *= 2
            self.convs.append(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=3, stride=1, padding=1))
        out_height //= 2
        out_width //= 2
        self.l1 = nn.Linear(out_height * out_width * out_channels, fc_units)
        self.l2 = nn.Linear(fc_units, fc_units)
        self.l3 = nn.Linear(fc_units, 10)
        self.act = activation
        self.pool = nn.MaxPool2d(2, 2)
    
    def forward(self, x):
        for conv in self.convs:
            x = self.pool(self.act(conv(x)))
        x = x.view(x.size()[0], -1)
        x = self.act(self.l1(x))
        x = self.act(self.l2(x))
        x = self.l3(x)
        return x

def get_optimizer(trial, model):
    optimizer_names = ('MomentumSGD', 'Adam')
    optimizer_name = trial.suggest_categorical('optimizer', optimizer_names)
    weight_decay = trial.suggest_float('weight_decay', 1e-10, 1e-3, log=True)
    if optimizer_name == optimizer_names[0]:
        lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
        optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay)
    else:
        lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    return optimizer, optimizer_name, lr, weight_decay

def objective(trial):
    num_epoch = trial.suggest_int("num_epoch", 10, 50)
    batch_size = trial.suggest_int("batch_size", 64, 256)
    fc_units = trial.suggest_int("fc_units", 1024, 4096)
    num_layer = trial.suggest_int("num_layer", 5, 7)
    activation, activation_name = get_activation(trial)

    device = "cuda" if torch.cuda.is_available() else "cpu"
    train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=batch_size, shuffle=False)
    criterion = nn.CrossEntropyLoss().to(device)
    model = CNN(activation, fc_units, num_layer).to(device)
    optimizer, optimizer_name, lr, weight_decay = get_optimizer(trial, model)
    print({
        "action": "objective", 
        "num_epoch": num_epoch,
        "activation_name": activation_name,
        "fc_units": fc_units,
        "num_layer": num_layer,
        "optimizer_name": optimizer_name,
        "lr": lr, 
        "weight_decay": weight_decay,})
    for epoch in range(1, num_epoch + 1):
        train_sum_loss, train_accuracy = train(
            model, device, train_loader, criterion, optimizer)
    test_accuracy = test(model, device, test_loader)
    return test_accuracy

# %%
study = optuna.create_study(
    direction="maximize", storage="sqlite:///optuna.db", 
    study_name="CNN", load_if_exists=True)
study.optimize(objective, n_trials=10)
# Out:
# [I 2023-03-20 16:17:57,472] A new study created in RDB with name: CNN
# {'action': 'objective', 'num_epoch': 41, 'activation_name': 'ELU', 'fc_units': 2091, 'num_layer': 7, 'optimizer_name': 'Adam', 'lr': 0.004585810865533606, 'weight_decay': 9.001636356893551e-05}
# {'action': 'train', 'mean_loss': 0.011719607520103455, 'accuracy': 0.38648}
# {'action': 'train', 'mean_loss': 0.007184911177158356, 'accuracy': 0.58432}
# {'action': 'train', 'mean_loss': 0.006401865640878677, 'accuracy': 0.63328}
# {'action': 'train', 'mean_loss': 0.005823105705976486, 'accuracy': 0.6669}
# {'action': 'train', 'mean_loss': 0.0053364636874198915, 'accuracy': 0.6959}
# {'action': 'train', 'mean_loss': 0.005091590056419373, 'accuracy': 0.71094}
# {'action': 'train', 'mean_loss': 0.004825899468660354, 'accuracy': 0.73018}
# {'action': 'train', 'mean_loss': 2.0531205676496027, 'accuracy': 0.55536}
# {'action': 'train', 'mean_loss': 0.020339992842674254, 'accuracy': 0.10282}
# {'action': 'train', 'mean_loss': 0.015185096502304077, 'accuracy': 0.11228}
# {'action': 'train', 'mean_loss': 0.015257702322006225, 'accuracy': 0.11604}
# {'action': 'train', 'mean_loss': 0.015314027070999145, 'accuracy': 0.11498}
# {'action': 'train', 'mean_loss': 0.015026837725639343, 'accuracy': 0.12162}
# {'action': 'train', 'mean_loss': 0.015219720811843872, 'accuracy': 0.12726}
# {'action': 'train', 'mean_loss': 0.014631265120506286, 'accuracy': 0.13558}
# {'action': 'train', 'mean_loss': 0.014627678203582763, 'accuracy': 0.14172}
# {'action': 'train', 'mean_loss': 0.015263057055473327, 'accuracy': 0.14448}
# {'action': 'train', 'mean_loss': 0.014335676779747009, 'accuracy': 0.15114}
# {'action': 'train', 'mean_loss': 0.014209825119972229, 'accuracy': 0.16548}
# {'action': 'train', 'mean_loss': 0.014117311096191406, 'accuracy': 0.16702}
# {'action': 'train', 'mean_loss': 0.013818189744949342, 'accuracy': 0.17636}
# {'action': 'train', 'mean_loss': 0.013745427522659302, 'accuracy': 0.17606}
# {'action': 'train', 'mean_loss': 0.013743396179676057, 'accuracy': 0.18064}
# {'action': 'train', 'mean_loss': 0.03052355516433716, 'accuracy': 0.1054}
# {'action': 'train', 'mean_loss': 0.018251909041404724, 'accuracy': 0.09914}
# {'action': 'train', 'mean_loss': 0.08729110473155975, 'accuracy': 0.09942}
# {'action': 'train', 'mean_loss': 0.014625735535621643, 'accuracy': 0.10028}
# {'action': 'train', 'mean_loss': 0.019506203899383547, 'accuracy': 0.099}
# {'action': 'train', 'mean_loss': 0.018962415432929994, 'accuracy': 0.10194}
# {'action': 'train', 'mean_loss': 0.017320862679481505, 'accuracy': 0.09782}
# {'action': 'train', 'mean_loss': 0.01792685950756073, 'accuracy': 0.10064}
# {'action': 'train', 'mean_loss': 0.01814300943374634, 'accuracy': 0.0978}
# {'action': 'train', 'mean_loss': 0.018357095704078674, 'accuracy': 0.09718}
# {'action': 'train', 'mean_loss': 0.016587336144447327, 'accuracy': 0.09922}
# {'action': 'train', 'mean_loss': 0.016540549788475037, 'accuracy': 0.10038}
# {'action': 'train', 'mean_loss': 0.017322382287979127, 'accuracy': 0.09998}
# {'action': 'train', 'mean_loss': 0.015429750423431397, 'accuracy': 0.09928}
# {'action': 'train', 'mean_loss': 0.015686384282112123, 'accuracy': 0.09972}
# {'action': 'train', 'mean_loss': 0.01790792161464691, 'accuracy': 0.10004}
# {'action': 'train', 'mean_loss': 0.018996004719734193, 'accuracy': 0.09786}
# {'action': 'train', 'mean_loss': 0.01628125985145569, 'accuracy': 0.1009}
# [I 2023-03-20 16:26:34,353] Trial 0 finished with value: 0.1 and parameters: {'num_epoch': 41, 'batch_size': 164, 'fc_units': 2091, 'num_layer': 7, 'activation': 'ELU', 'optimizer': 'Adam', 'weight_decay': 9.001636356893551e-05, 'lr': 0.004585810865533606}. Best is trial 0 with value: 0.1.
# {'action': 'test', 'accuracy': 0.1}
# {'action': 'objective', 'num_epoch': 37, 'activation_name': 'ReLU', 'fc_units': 2101, 'num_layer': 6, 'optimizer_name': 'MomentumSGD', 'lr': 0.0003525863051047292, 'weight_decay': 1.425570712003436e-09}
# {'action': 'train', 'mean_loss': 0.009531156988143922, 'accuracy': 0.11164}
# {'action': 'train', 'mean_loss': 0.009528208575248718, 'accuracy': 0.10952}
# {'action': 'train', 'mean_loss': 0.009525134897232055, 'accuracy': 0.13462}
# {'action': 'train', 'mean_loss': 0.00952175066947937, 'accuracy': 0.15786}
# {'action': 'train', 'mean_loss': 0.009517834124565125, 'accuracy': 0.16122}
# {'action': 'train', 'mean_loss': 0.00951314311504364, 'accuracy': 0.14888}
# {'action': 'train', 'mean_loss': 0.0095074764919281, 'accuracy': 0.13236}
# {'action': 'train', 'mean_loss': 0.009500225005149842, 'accuracy': 0.1263}
# {'action': 'train', 'mean_loss': 0.0094909113073349, 'accuracy': 0.13094}
# {'action': 'train', 'mean_loss': 0.00947894371986389, 'accuracy': 0.12504}
# {'action': 'train', 'mean_loss': 0.009463173623085021, 'accuracy': 0.1289}
# {'action': 'train', 'mean_loss': 0.009442177605628967, 'accuracy': 0.13542}
# {'action': 'train', 'mean_loss': 0.00941422917842865, 'accuracy': 0.1468}
# {'action': 'train', 'mean_loss': 0.009375601234436036, 'accuracy': 0.15956}
# {'action': 'train', 'mean_loss': 0.009319693522453308, 'accuracy': 0.17038}
# {'action': 'train', 'mean_loss': 0.009237585725784302, 'accuracy': 0.17952}
# {'action': 'train', 'mean_loss': 0.009126957201957702, 'accuracy': 0.18926}
# {'action': 'train', 'mean_loss': 0.009021074481010437, 'accuracy': 0.1946}
# {'action': 'train', 'mean_loss': 0.008954794688224792, 'accuracy': 0.20036}
# {'action': 'train', 'mean_loss': 0.008903895382881164, 'accuracy': 0.21214}
# {'action': 'train', 'mean_loss': 0.008848574652671814, 'accuracy': 0.22116}
# {'action': 'train', 'mean_loss': 0.008782366333007812, 'accuracy': 0.23286}
# {'action': 'train', 'mean_loss': 0.008698456997871399, 'accuracy': 0.24468}
# {'action': 'train', 'mean_loss': 0.008584804403781891, 'accuracy': 0.25992}
# {'action': 'train', 'mean_loss': 0.008438538706302642, 'accuracy': 0.27416}
# {'action': 'train', 'mean_loss': 0.008287555046081543, 'accuracy': 0.28404}
# {'action': 'train', 'mean_loss': 0.008173903295993806, 'accuracy': 0.29178}
# {'action': 'train', 'mean_loss': 0.008100006952285766, 'accuracy': 0.29958}
# {'action': 'train', 'mean_loss': 0.008031704566478729, 'accuracy': 0.30504}
# {'action': 'train', 'mean_loss': 0.00796981458902359, 'accuracy': 0.30792}
# {'action': 'train', 'mean_loss': 0.007903377277851105, 'accuracy': 0.3142}
# {'action': 'train', 'mean_loss': 0.007828048276901246, 'accuracy': 0.32166}
# {'action': 'train', 'mean_loss': 0.007744068627357483, 'accuracy': 0.32772}
# {'action': 'train', 'mean_loss': 0.007664143257141113, 'accuracy': 0.33742}
# {'action': 'train', 'mean_loss': 0.007572872428894043, 'accuracy': 0.34296}
# {'action': 'train', 'mean_loss': 0.007482540600299835, 'accuracy': 0.3527}
# {'action': 'train', 'mean_loss': 0.007399375534057617, 'accuracy': 0.3606}
# [I 2023-03-20 16:33:33,538] Trial 1 finished with value: 0.3707 and parameters: {'num_epoch': 37, 'batch_size': 242, 'fc_units': 2101, 'num_layer': 6, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'weight_decay': 1.425570712003436e-09, 'lr': 0.0003525863051047292}. Best is trial 1 with value: 0.3707.
# {'action': 'test', 'accuracy': 0.3707}
# {'action': 'objective', 'num_epoch': 27, 'activation_name': 'ELU', 'fc_units': 2755, 'num_layer': 5, 'optimizer_name': 'Adam', 'lr': 0.00011960441454274021, 'weight_decay': 1.8744621637622562e-08}
# {'action': 'train', 'mean_loss': 0.006788593428134918, 'accuracy': 0.38646}
# {'action': 'train', 'mean_loss': 0.005725726296901703, 'accuracy': 0.48626}
# {'action': 'train', 'mean_loss': 0.005255042066574097, 'accuracy': 0.53126}
# {'action': 'train', 'mean_loss': 0.004946095387935639, 'accuracy': 0.56018}
# {'action': 'train', 'mean_loss': 0.004708562693595886, 'accuracy': 0.58066}
# {'action': 'train', 'mean_loss': 0.004540925097465515, 'accuracy': 0.59726}
# {'action': 'train', 'mean_loss': 0.004381102088689804, 'accuracy': 0.61024}
# {'action': 'train', 'mean_loss': 0.004275233733654022, 'accuracy': 0.61924}
# {'action': 'train', 'mean_loss': 0.004171485720872879, 'accuracy': 0.6303}
# {'action': 'train', 'mean_loss': 0.004078167088031769, 'accuracy': 0.63812}
# {'action': 'train', 'mean_loss': 0.003998372541666031, 'accuracy': 0.6467}
# {'action': 'train', 'mean_loss': 0.003941036212444305, 'accuracy': 0.6523}
# {'action': 'train', 'mean_loss': 0.0038803564441204073, 'accuracy': 0.65718}
# {'action': 'train', 'mean_loss': 0.0038442870235443115, 'accuracy': 0.66146}
# {'action': 'train', 'mean_loss': 0.003787883793115616, 'accuracy': 0.66518}
# {'action': 'train', 'mean_loss': 0.003756415320634842, 'accuracy': 0.66736}
# {'action': 'train', 'mean_loss': 0.0036821777951717375, 'accuracy': 0.67596}
# {'action': 'train', 'mean_loss': 0.0036261125576496126, 'accuracy': 0.67858}
# {'action': 'train', 'mean_loss': 0.003636185884475708, 'accuracy': 0.67836}
# {'action': 'train', 'mean_loss': 0.0035708228957653044, 'accuracy': 0.6831}
# {'action': 'train', 'mean_loss': 0.003541926440000534, 'accuracy': 0.6882}
# {'action': 'train', 'mean_loss': 0.0034989426350593568, 'accuracy': 0.69132}
# {'action': 'train', 'mean_loss': 0.003464653080701828, 'accuracy': 0.69348}
# {'action': 'train', 'mean_loss': 0.0034299557638168333, 'accuracy': 0.69576}
# {'action': 'train', 'mean_loss': 0.0033904424941539764, 'accuracy': 0.69802}
# {'action': 'train', 'mean_loss': 0.00335940633893013, 'accuracy': 0.703}
# {'action': 'train', 'mean_loss': 0.0033417091381549835, 'accuracy': 0.7026}
# [I 2023-03-20 16:39:11,559] Trial 2 finished with value: 0.6357 and parameters: {'num_epoch': 27, 'batch_size': 254, 'fc_units': 2755, 'num_layer': 5, 'activation': 'ELU', 'optimizer': 'Adam', 'weight_decay': 1.8744621637622562e-08, 'lr': 0.00011960441454274021}. Best is trial 2 with value: 0.6357.
# {'action': 'test', 'accuracy': 0.6357}
# {'action': 'objective', 'num_epoch': 45, 'activation_name': 'ELU', 'fc_units': 3241, 'num_layer': 6, 'optimizer_name': 'MomentumSGD', 'lr': 0.0018303221828338506, 'weight_decay': 1.4616122048756746e-06}
# {'action': 'train', 'mean_loss': 0.025294790766239167, 'accuracy': 0.20358}
# {'action': 'train', 'mean_loss': 0.02108346347570419, 'accuracy': 0.35926}
# {'action': 'train', 'mean_loss': 0.018368250682353975, 'accuracy': 0.43614}
# {'action': 'train', 'mean_loss': 0.01705931688785553, 'accuracy': 0.47874}
# {'action': 'train', 'mean_loss': 0.015898083000183104, 'accuracy': 0.51606}
# {'action': 'train', 'mean_loss': 0.014876388852596283, 'accuracy': 0.54826}
# {'action': 'train', 'mean_loss': 0.013917396413087845, 'accuracy': 0.57758}
# {'action': 'train', 'mean_loss': 0.013166468287706375, 'accuracy': 0.59956}
# {'action': 'train', 'mean_loss': 0.012477254512310028, 'accuracy': 0.62058}
# {'action': 'train', 'mean_loss': 0.011937195738554, 'accuracy': 0.64014}
# {'action': 'train', 'mean_loss': 0.011446953959465028, 'accuracy': 0.6547}
# {'action': 'train', 'mean_loss': 0.010948244777917861, 'accuracy': 0.67074}
# {'action': 'train', 'mean_loss': 0.010504865641593933, 'accuracy': 0.68472}
# {'action': 'train', 'mean_loss': 0.010121045354604721, 'accuracy': 0.69608}
# {'action': 'train', 'mean_loss': 0.009812866216897965, 'accuracy': 0.70634}
# {'action': 'train', 'mean_loss': 0.009459489492177963, 'accuracy': 0.7158}
# {'action': 'train', 'mean_loss': 0.009158489282131196, 'accuracy': 0.72654}
# {'action': 'train', 'mean_loss': 0.008834994357824326, 'accuracy': 0.73682}
# {'action': 'train', 'mean_loss': 0.008523905384540557, 'accuracy': 0.74536}
# {'action': 'train', 'mean_loss': 0.008257147164940835, 'accuracy': 0.75326}
# {'action': 'train', 'mean_loss': 0.007971690856218338, 'accuracy': 0.76186}
# {'action': 'train', 'mean_loss': 0.007699791932106018, 'accuracy': 0.76922}
# {'action': 'train', 'mean_loss': 0.00737234701693058, 'accuracy': 0.78078}
# {'action': 'train', 'mean_loss': 0.007109734121561051, 'accuracy': 0.78774}
# {'action': 'train', 'mean_loss': 0.006836404134631157, 'accuracy': 0.79502}
# {'action': 'train', 'mean_loss': 0.006563594505786896, 'accuracy': 0.80348}
# {'action': 'train', 'mean_loss': 0.006285459822416305, 'accuracy': 0.81078}
# {'action': 'train', 'mean_loss': 0.005943251625597477, 'accuracy': 0.82244}
# {'action': 'train', 'mean_loss': 0.005653191433250904, 'accuracy': 0.8317}
# {'action': 'train', 'mean_loss': 0.0053482959964871405, 'accuracy': 0.83864}
# {'action': 'train', 'mean_loss': 0.005028259475231171, 'accuracy': 0.84924}
# {'action': 'train', 'mean_loss': 0.004700170134603977, 'accuracy': 0.85894}
# {'action': 'train', 'mean_loss': 0.004359662672281266, 'accuracy': 0.87008}
# {'action': 'train', 'mean_loss': 0.00404997538626194, 'accuracy': 0.87832}
# {'action': 'train', 'mean_loss': 0.0037558736979961395, 'accuracy': 0.88722}
# {'action': 'train', 'mean_loss': 0.003361977207660675, 'accuracy': 0.89928}
# {'action': 'train', 'mean_loss': 0.003001573674082756, 'accuracy': 0.91002}
# {'action': 'train', 'mean_loss': 0.0026756508858501913, 'accuracy': 0.92012}
# {'action': 'train', 'mean_loss': 0.002336058425232768, 'accuracy': 0.93058}
# {'action': 'train', 'mean_loss': 0.001997450048774481, 'accuracy': 0.94106}
# {'action': 'train', 'mean_loss': 0.0017057420751452445, 'accuracy': 0.95006}
# {'action': 'train', 'mean_loss': 0.0014558416328579187, 'accuracy': 0.95802}
# {'action': 'train', 'mean_loss': 0.0010995310575515032, 'accuracy': 0.97}
# {'action': 'train', 'mean_loss': 0.0009758030544966459, 'accuracy': 0.97318}
# {'action': 'train', 'mean_loss': 0.0008636755152232945, 'accuracy': 0.97574}
# [I 2023-03-20 16:49:59,403] Trial 3 finished with value: 0.7292 and parameters: {'num_epoch': 45, 'batch_size': 86, 'fc_units': 3241, 'num_layer': 6, 'activation': 'ELU', 'optimizer': 'MomentumSGD', 'weight_decay': 1.4616122048756746e-06, 'lr': 0.0018303221828338506}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.7292}
# {'action': 'objective', 'num_epoch': 49, 'activation_name': 'ReLU', 'fc_units': 1496, 'num_layer': 6, 'optimizer_name': 'Adam', 'lr': 0.004220359557881649, 'weight_decay': 0.0006939160468570179}
# {'action': 'train', 'mean_loss': 0.00909331269979477, 'accuracy': 0.30552}
# {'action': 'train', 'mean_loss': 0.007102437500953674, 'accuracy': 0.47926}
# {'action': 'train', 'mean_loss': 0.0062803859186172485, 'accuracy': 0.54388}
# {'action': 'train', 'mean_loss': 0.005638876625299454, 'accuracy': 0.59508}
# {'action': 'train', 'mean_loss': 0.005221017805337906, 'accuracy': 0.62792}
# {'action': 'train', 'mean_loss': 0.004878550741672516, 'accuracy': 0.65214}
# {'action': 'train', 'mean_loss': 0.004632216012477874, 'accuracy': 0.6718}
# {'action': 'train', 'mean_loss': 0.004415258774757385, 'accuracy': 0.68752}
# {'action': 'train', 'mean_loss': 0.004267326225042343, 'accuracy': 0.69918}
# {'action': 'train', 'mean_loss': 0.004147193398475647, 'accuracy': 0.70734}
# {'action': 'train', 'mean_loss': 0.0039768993151187895, 'accuracy': 0.72152}
# {'action': 'train', 'mean_loss': 0.003931335904598236, 'accuracy': 0.7211}
# {'action': 'train', 'mean_loss': 0.0038213638925552367, 'accuracy': 0.72868}
# {'action': 'train', 'mean_loss': 0.003781679490804672, 'accuracy': 0.73244}
# {'action': 'train', 'mean_loss': 0.0036779870975017547, 'accuracy': 0.74136}
# {'action': 'train', 'mean_loss': 0.0036329737997055052, 'accuracy': 0.74462}
# {'action': 'train', 'mean_loss': 0.0035482119232416154, 'accuracy': 0.7504}
# {'action': 'train', 'mean_loss': 0.0035150530928373335, 'accuracy': 0.75336}
# {'action': 'train', 'mean_loss': 0.0034346061670780183, 'accuracy': 0.75726}
# {'action': 'train', 'mean_loss': 0.003409068740606308, 'accuracy': 0.76062}
# {'action': 'train', 'mean_loss': 0.0033657676196098326, 'accuracy': 0.76354}
# {'action': 'train', 'mean_loss': 0.0033093251729011536, 'accuracy': 0.76674}
# {'action': 'train', 'mean_loss': 0.0032943253058195115, 'accuracy': 0.76802}
# {'action': 'train', 'mean_loss': 0.0032630789268016814, 'accuracy': 0.77146}
# {'action': 'train', 'mean_loss': 0.003198644953966141, 'accuracy': 0.7739}
# {'action': 'train', 'mean_loss': 0.0032007764315605163, 'accuracy': 0.77486}
# {'action': 'train', 'mean_loss': 0.0031348593193292616, 'accuracy': 0.78024}
# {'action': 'train', 'mean_loss': 0.0031040050005912783, 'accuracy': 0.7822}
# {'action': 'train', 'mean_loss': 0.0030870362401008607, 'accuracy': 0.78172}
# {'action': 'train', 'mean_loss': 0.0030917279106378553, 'accuracy': 0.78372}
# {'action': 'train', 'mean_loss': 0.003050972363948822, 'accuracy': 0.78472}
# {'action': 'train', 'mean_loss': 0.003008365904688835, 'accuracy': 0.78716}
# {'action': 'train', 'mean_loss': 0.003000273159146309, 'accuracy': 0.78762}
# {'action': 'train', 'mean_loss': 0.0029993087714910507, 'accuracy': 0.7894}
# {'action': 'train', 'mean_loss': 0.002967848427891731, 'accuracy': 0.79154}
# {'action': 'train', 'mean_loss': 0.0029555195361375807, 'accuracy': 0.79236}
# {'action': 'train', 'mean_loss': 0.0029405950963497162, 'accuracy': 0.79256}
# {'action': 'train', 'mean_loss': 0.0028989504301548, 'accuracy': 0.79704}
# {'action': 'train', 'mean_loss': 0.0028931412053108214, 'accuracy': 0.7975}
# {'action': 'train', 'mean_loss': 0.002872454710006714, 'accuracy': 0.79684}
# {'action': 'train', 'mean_loss': 0.002909134069681168, 'accuracy': 0.79286}
# {'action': 'train', 'mean_loss': 0.0028504169416427613, 'accuracy': 0.79954}
# {'action': 'train', 'mean_loss': 0.0028960052943229676, 'accuracy': 0.7951}
# {'action': 'train', 'mean_loss': 0.002809674859046936, 'accuracy': 0.80202}
# {'action': 'train', 'mean_loss': 0.002803721929192543, 'accuracy': 0.80244}
# {'action': 'train', 'mean_loss': 0.002769058417081833, 'accuracy': 0.80518}
# {'action': 'train', 'mean_loss': 0.00277149547457695, 'accuracy': 0.80608}
# {'action': 'train', 'mean_loss': 0.0027737126302719117, 'accuracy': 0.80328}
# {'action': 'train', 'mean_loss': 0.00277864348590374, 'accuracy': 0.8019}
# [I 2023-03-20 16:59:07,580] Trial 4 finished with value: 0.7153 and parameters: {'num_epoch': 49, 'batch_size': 201, 'fc_units': 1496, 'num_layer': 6, 'activation': 'ReLU', 'optimizer': 'Adam', 'weight_decay': 0.0006939160468570179, 'lr': 0.004220359557881649}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.7153}
# {'action': 'objective', 'num_epoch': 19, 'activation_name': 'ELU', 'fc_units': 3140, 'num_layer': 6, 'optimizer_name': 'MomentumSGD', 'lr': 0.0001160053277802786, 'weight_decay': 1.0532124982330885e-07}
# {'action': 'train', 'mean_loss': 0.03487002031326294, 'accuracy': 0.11572}
# {'action': 'train', 'mean_loss': 0.03476797332763672, 'accuracy': 0.10904}
# {'action': 'train', 'mean_loss': 0.034637117490768435, 'accuracy': 0.13192}
# {'action': 'train', 'mean_loss': 0.03443514187335968, 'accuracy': 0.14652}
# {'action': 'train', 'mean_loss': 0.034073926911354066, 'accuracy': 0.19814}
# {'action': 'train', 'mean_loss': 0.03333650982379913, 'accuracy': 0.23712}
# {'action': 'train', 'mean_loss': 0.03200572922468185, 'accuracy': 0.257}
# {'action': 'train', 'mean_loss': 0.03091896845340729, 'accuracy': 0.27148}
# {'action': 'train', 'mean_loss': 0.030470668926239015, 'accuracy': 0.2821}
# {'action': 'train', 'mean_loss': 0.030174583973884582, 'accuracy': 0.2892}
# {'action': 'train', 'mean_loss': 0.0298958793592453, 'accuracy': 0.2983}
# {'action': 'train', 'mean_loss': 0.02958691320180893, 'accuracy': 0.30696}
# {'action': 'train', 'mean_loss': 0.029225742983818054, 'accuracy': 0.3191}
# {'action': 'train', 'mean_loss': 0.02881077007293701, 'accuracy': 0.33186}
# {'action': 'train', 'mean_loss': 0.02834144544839859, 'accuracy': 0.34568}
# {'action': 'train', 'mean_loss': 0.027850051736831666, 'accuracy': 0.35858}
# {'action': 'train', 'mean_loss': 0.027346330223083495, 'accuracy': 0.36866}
# {'action': 'train', 'mean_loss': 0.026867895114421843, 'accuracy': 0.37892}
# {'action': 'train', 'mean_loss': 0.0264220911693573, 'accuracy': 0.38594}
# [I 2023-03-20 17:03:54,518] Trial 5 finished with value: 0.3969 and parameters: {'num_epoch': 19, 'batch_size': 66, 'fc_units': 3140, 'num_layer': 6, 'activation': 'ELU', 'optimizer': 'MomentumSGD', 'weight_decay': 1.0532124982330885e-07, 'lr': 0.0001160053277802786}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.3969}
# {'action': 'objective', 'num_epoch': 21, 'activation_name': 'ReLU', 'fc_units': 1808, 'num_layer': 6, 'optimizer_name': 'MomentumSGD', 'lr': 0.00020921996659466465, 'weight_decay': 0.0005581012288646244}
# {'action': 'train', 'mean_loss': 0.02214965557575226, 'accuracy': 0.10632}
# {'action': 'train', 'mean_loss': 0.022147761754989625, 'accuracy': 0.11126}
# {'action': 'train', 'mean_loss': 0.022145998039245607, 'accuracy': 0.12298}
# {'action': 'train', 'mean_loss': 0.02214434310913086, 'accuracy': 0.12542}
# {'action': 'train', 'mean_loss': 0.022142651839256285, 'accuracy': 0.14868}
# {'action': 'train', 'mean_loss': 0.022140907430648803, 'accuracy': 0.14924}
# {'action': 'train', 'mean_loss': 0.02213900532722473, 'accuracy': 0.14352}
# {'action': 'train', 'mean_loss': 0.02213695001125336, 'accuracy': 0.16308}
# {'action': 'train', 'mean_loss': 0.02213462959766388, 'accuracy': 0.17902}
# {'action': 'train', 'mean_loss': 0.022131980299949647, 'accuracy': 0.16868}
# {'action': 'train', 'mean_loss': 0.022128922643661498, 'accuracy': 0.18386}
# {'action': 'train', 'mean_loss': 0.0221253796005249, 'accuracy': 0.19194}
# {'action': 'train', 'mean_loss': 0.022121223311424257, 'accuracy': 0.19332}
# {'action': 'train', 'mean_loss': 0.022116222743988036, 'accuracy': 0.19944}
# {'action': 'train', 'mean_loss': 0.022110193042755126, 'accuracy': 0.1942}
# {'action': 'train', 'mean_loss': 0.022102829461097716, 'accuracy': 0.20812}
# {'action': 'train', 'mean_loss': 0.022093548493385316, 'accuracy': 0.2038}
# {'action': 'train', 'mean_loss': 0.022081698770523073, 'accuracy': 0.20348}
# {'action': 'train', 'mean_loss': 0.02206617304801941, 'accuracy': 0.2077}
# {'action': 'train', 'mean_loss': 0.02204516302585602, 'accuracy': 0.20524}
# {'action': 'train', 'mean_loss': 0.02201570408821106, 'accuracy': 0.21308}
# [I 2023-03-20 17:08:07,089] Trial 6 finished with value: 0.212 and parameters: {'num_epoch': 21, 'batch_size': 104, 'fc_units': 1808, 'num_layer': 6, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'weight_decay': 0.0005581012288646244, 'lr': 0.00020921996659466465}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.212}
# {'action': 'objective', 'num_epoch': 12, 'activation_name': 'ReLU', 'fc_units': 1538, 'num_layer': 7, 'optimizer_name': 'Adam', 'lr': 0.002895641762927132, 'weight_decay': 1.5294588677881859e-06}
# {'action': 'train', 'mean_loss': 0.008574312498569488, 'accuracy': 0.32104}
# {'action': 'train', 'mean_loss': 0.00639941799402237, 'accuracy': 0.5115}
# {'action': 'train', 'mean_loss': 0.005530523422956467, 'accuracy': 0.5904}
# {'action': 'train', 'mean_loss': 0.004913119673728943, 'accuracy': 0.63954}
# {'action': 'train', 'mean_loss': 0.0044913748598098754, 'accuracy': 0.6729}
# {'action': 'train', 'mean_loss': 0.0041580005633831026, 'accuracy': 0.69458}
# {'action': 'train', 'mean_loss': 0.003890778361558914, 'accuracy': 0.71604}
# {'action': 'train', 'mean_loss': 0.0036572927367687223, 'accuracy': 0.73096}
# {'action': 'train', 'mean_loss': 0.003399243003129959, 'accuracy': 0.7489}
# {'action': 'train', 'mean_loss': 0.0031827754980325697, 'accuracy': 0.76594}
# {'action': 'train', 'mean_loss': 0.003019496371150017, 'accuracy': 0.7762}
# {'action': 'train', 'mean_loss': 0.002850980694890022, 'accuracy': 0.79062}
# [I 2023-03-20 17:10:28,095] Trial 7 finished with value: 0.6877 and parameters: {'num_epoch': 12, 'batch_size': 206, 'fc_units': 1538, 'num_layer': 7, 'activation': 'ReLU', 'optimizer': 'Adam', 'weight_decay': 1.5294588677881859e-06, 'lr': 0.002895641762927132}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.6877}
# {'action': 'objective', 'num_epoch': 47, 'activation_name': 'ELU', 'fc_units': 2684, 'num_layer': 7, 'optimizer_name': 'MomentumSGD', 'lr': 0.00034812015644491415, 'weight_decay': 1.215698389346229e-10}
# {'action': 'train', 'mean_loss': 0.013584067769050598, 'accuracy': 0.1}
# {'action': 'train', 'mean_loss': 0.013578125610351563, 'accuracy': 0.1044}
# {'action': 'train', 'mean_loss': 0.013571721925735473, 'accuracy': 0.13314}
# {'action': 'train', 'mean_loss': 0.01356360234260559, 'accuracy': 0.13578}
# {'action': 'train', 'mean_loss': 0.013552246265411377, 'accuracy': 0.15214}
# {'action': 'train', 'mean_loss': 0.013534687094688415, 'accuracy': 0.13574}
# {'action': 'train', 'mean_loss': 0.013505833520889281, 'accuracy': 0.14158}
# {'action': 'train', 'mean_loss': 0.013452882242202759, 'accuracy': 0.15086}
# {'action': 'train', 'mean_loss': 0.013343793807029724, 'accuracy': 0.17348}
# {'action': 'train', 'mean_loss': 0.013070450177192688, 'accuracy': 0.19722}
# {'action': 'train', 'mean_loss': 0.012568285136222839, 'accuracy': 0.21124}
# {'action': 'train', 'mean_loss': 0.01225257881641388, 'accuracy': 0.23126}
# {'action': 'train', 'mean_loss': 0.012104547774791717, 'accuracy': 0.2453}
# {'action': 'train', 'mean_loss': 0.012008444943428039, 'accuracy': 0.25028}
# {'action': 'train', 'mean_loss': 0.011924908754825592, 'accuracy': 0.2578}
# {'action': 'train', 'mean_loss': 0.011857400250434875, 'accuracy': 0.26154}
# {'action': 'train', 'mean_loss': 0.011794586582183839, 'accuracy': 0.26934}
# {'action': 'train', 'mean_loss': 0.011731443207263947, 'accuracy': 0.27146}
# {'action': 'train', 'mean_loss': 0.011672296082973481, 'accuracy': 0.27698}
# {'action': 'train', 'mean_loss': 0.011596592082977294, 'accuracy': 0.28558}
# {'action': 'train', 'mean_loss': 0.011519890496730804, 'accuracy': 0.28836}
# {'action': 'train', 'mean_loss': 0.011440065822601318, 'accuracy': 0.29426}
# {'action': 'train', 'mean_loss': 0.011349588243961335, 'accuracy': 0.30264}
# {'action': 'train', 'mean_loss': 0.01124140597820282, 'accuracy': 0.3101}
# {'action': 'train', 'mean_loss': 0.011113811972141266, 'accuracy': 0.32006}
# {'action': 'train', 'mean_loss': 0.010956153559684753, 'accuracy': 0.33232}
# {'action': 'train', 'mean_loss': 0.010766824791431427, 'accuracy': 0.34812}
# {'action': 'train', 'mean_loss': 0.010561766571998596, 'accuracy': 0.3612}
# {'action': 'train', 'mean_loss': 0.010335647575855256, 'accuracy': 0.3732}
# {'action': 'train', 'mean_loss': 0.010140794651508332, 'accuracy': 0.38514}
# {'action': 'train', 'mean_loss': 0.009958660733699798, 'accuracy': 0.3939}
# {'action': 'train', 'mean_loss': 0.009818670399188996, 'accuracy': 0.39924}
# {'action': 'train', 'mean_loss': 0.009699469947814942, 'accuracy': 0.40674}
# {'action': 'train', 'mean_loss': 0.009581864938735961, 'accuracy': 0.41274}
# {'action': 'train', 'mean_loss': 0.009451291916370392, 'accuracy': 0.42022}
# {'action': 'train', 'mean_loss': 0.009340990660190581, 'accuracy': 0.42624}
# {'action': 'train', 'mean_loss': 0.009242748079299926, 'accuracy': 0.4311}
# {'action': 'train', 'mean_loss': 0.009127810459136963, 'accuracy': 0.44076}
# {'action': 'train', 'mean_loss': 0.009034591825008393, 'accuracy': 0.44536}
# {'action': 'train', 'mean_loss': 0.00892883296251297, 'accuracy': 0.45216}
# {'action': 'train', 'mean_loss': 0.008836826860904694, 'accuracy': 0.45796}
# {'action': 'train', 'mean_loss': 0.008771516683101653, 'accuracy': 0.46232}
# {'action': 'train', 'mean_loss': 0.008687487435340882, 'accuracy': 0.46826}
# {'action': 'train', 'mean_loss': 0.0085861967086792, 'accuracy': 0.47452}
# {'action': 'train', 'mean_loss': 0.008526589107513428, 'accuracy': 0.48014}
# {'action': 'train', 'mean_loss': 0.008458308029174804, 'accuracy': 0.48276}
# {'action': 'train', 'mean_loss': 0.008423776333332062, 'accuracy': 0.48782}
# [I 2023-03-20 17:20:23,951] Trial 8 finished with value: 0.4767 and parameters: {'num_epoch': 47, 'batch_size': 170, 'fc_units': 2684, 'num_layer': 7, 'activation': 'ELU', 'optimizer': 'MomentumSGD', 'weight_decay': 1.215698389346229e-10, 'lr': 0.00034812015644491415}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.4767}
# {'action': 'objective', 'num_epoch': 39, 'activation_name': 'ReLU', 'fc_units': 2791, 'num_layer': 7, 'optimizer_name': 'MomentumSGD', 'lr': 0.004506971106135137, 'weight_decay': 1.2948405912708029e-08}
# {'action': 'train', 'mean_loss': 0.03347010161399841, 'accuracy': 0.13996}
# {'action': 'train', 'mean_loss': 0.028178699748516084, 'accuracy': 0.28212}
# {'action': 'train', 'mean_loss': 0.023576230781078338, 'accuracy': 0.41006}
# {'action': 'train', 'mean_loss': 0.020550621045827864, 'accuracy': 0.49088}
# {'action': 'train', 'mean_loss': 0.018471933641433715, 'accuracy': 0.54524}
# {'action': 'train', 'mean_loss': 0.01665387326002121, 'accuracy': 0.59656}
# {'action': 'train', 'mean_loss': 0.015062288182973862, 'accuracy': 0.6361}
# {'action': 'train', 'mean_loss': 0.013763211636543274, 'accuracy': 0.66994}
# {'action': 'train', 'mean_loss': 0.012699568895697594, 'accuracy': 0.69814}
# {'action': 'train', 'mean_loss': 0.011529677755832673, 'accuracy': 0.72436}
# {'action': 'train', 'mean_loss': 0.010605144187808037, 'accuracy': 0.74686}
# {'action': 'train', 'mean_loss': 0.009679971212744713, 'accuracy': 0.76744}
# {'action': 'train', 'mean_loss': 0.008711288980841636, 'accuracy': 0.7915}
# {'action': 'train', 'mean_loss': 0.007846934331059456, 'accuracy': 0.81222}
# {'action': 'train', 'mean_loss': 0.006956022101640701, 'accuracy': 0.83416}
# {'action': 'train', 'mean_loss': 0.006089700487852096, 'accuracy': 0.8522}
# {'action': 'train', 'mean_loss': 0.005163509747684002, 'accuracy': 0.87482}
# {'action': 'train', 'mean_loss': 0.004303468912392854, 'accuracy': 0.8958}
# {'action': 'train', 'mean_loss': 0.0036232911518216133, 'accuracy': 0.9124}
# {'action': 'train', 'mean_loss': 0.0028524246203899383, 'accuracy': 0.93104}
# {'action': 'train', 'mean_loss': 0.0024769193179905416, 'accuracy': 0.94048}
# {'action': 'train', 'mean_loss': 0.0019203303064778447, 'accuracy': 0.95408}
# {'action': 'train', 'mean_loss': 0.0016953591151535512, 'accuracy': 0.95918}
# {'action': 'train', 'mean_loss': 0.0015269552377425134, 'accuracy': 0.96348}
# {'action': 'train', 'mean_loss': 0.0012836286110430957, 'accuracy': 0.96934}
# {'action': 'train', 'mean_loss': 0.0012021397958975285, 'accuracy': 0.9712}
# {'action': 'train', 'mean_loss': 0.001028468120219186, 'accuracy': 0.97606}
# {'action': 'train', 'mean_loss': 0.0008870515794493258, 'accuracy': 0.9797}
# {'action': 'train', 'mean_loss': 0.0009314088714309037, 'accuracy': 0.97814}
# {'action': 'train', 'mean_loss': 0.0007889370108954608, 'accuracy': 0.98196}
# {'action': 'train', 'mean_loss': 0.0005895547328074463, 'accuracy': 0.9861}
# {'action': 'train', 'mean_loss': 0.0006968287873920054, 'accuracy': 0.98398}
# {'action': 'train', 'mean_loss': 0.00025291730644064957, 'accuracy': 0.99464}
# {'action': 'train', 'mean_loss': 0.0005135236647643615, 'accuracy': 0.9881}
# {'action': 'train', 'mean_loss': 0.0008082133171299938, 'accuracy': 0.98102}
# {'action': 'train', 'mean_loss': 0.00042261785235255954, 'accuracy': 0.99064}
# {'action': 'train', 'mean_loss': 0.0001808825986654847, 'accuracy': 0.9963}
# {'action': 'train', 'mean_loss': 0.00017031927803822327, 'accuracy': 0.99622}
# {'action': 'train', 'mean_loss': 0.0005930075712502002, 'accuracy': 0.98634}
# [I 2023-03-20 17:30:02,439] Trial 9 finished with value: 0.7111 and parameters: {'num_epoch': 39, 'batch_size': 68, 'fc_units': 2791, 'num_layer': 7, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'weight_decay': 1.2948405912708029e-08, 'lr': 0.004506971106135137}. Best is trial 3 with value: 0.7292.
# {'action': 'test', 'accuracy': 0.7111}

# %%
best_params = study.best_params
best_value = study.best_value
print(best_params)
print(best_value)
# Out:
# {'activation': 'ELU', 'batch_size': 86, 'fc_units': 3241, 'lr': 0.0018303221828338506, 'num_epoch': 45, 'num_layer': 6, 'optimizer': 'MomentumSGD', 'weight_decay': 1.4616122048756746e-06}
# 0.7292

# %%
optuna.visualization.plot_param_importances(
    study=study,
    params=["num_epoch", "batch_size", "fc_units", "num_layer", "activation", "optimizer", "weight_decay", "lr"]
).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="801b6b03-819d-40ef-802b-aaa8ebd7da74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("801b6b03-819d-40ef-802b-aaa8ebd7da74")) {                    Plotly.newPlot(                        "801b6b03-819d-40ef-802b-aaa8ebd7da74",                        [{"cliponaxis":false,"hovertemplate":["num_layer (IntDistribution): 0.013909627078024296<extra></extra>","activation (CategoricalDistribution): 0.0339793954771276<extra></extra>","optimizer (CategoricalDistribution): 0.04369072635352597<extra></extra>","batch_size (IntDistribution): 0.0669323109250249<extra></extra>","num_epoch (IntDistribution): 0.07265141802587026<extra></extra>","fc_units (IntDistribution): 0.09953099301560926<extra></extra>","weight_decay (FloatDistribution): 0.18246964044742292<extra></extra>","lr (FloatDistribution): 0.4868358886773947<extra></extra>"],"marker":{"color":"rgb(66,146,198)"},"orientation":"h","text":["0.01","0.03","0.04","0.07","0.07","0.10","0.18","0.49"],"textposition":"outside","x":[0.013909627078024296,0.0339793954771276,0.04369072635352597,0.0669323109250249,0.07265141802587026,0.09953099301560926,0.18246964044742292,0.4868358886773947],"y":["num_layer","activation","optimizer","batch_size","num_epoch","fc_units","weight_decay","lr"],"type":"bar"}],                        {"showlegend":false,"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Importance for Objective Value"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666 ...

# %%
df = study.trials_dataframe()
df.sort_values("value", ascending=False)
# Out:
#    number   value             datetime_start          datetime_complete  \
# 3       3  0.7292 2023-03-20 16:39:11.568233 2023-03-20 16:49:59.384006
# 4       4  0.7153 2023-03-20 16:49:59.411419 2023-03-20 16:59:07.558789
# 9       9  0.7111 2023-03-20 17:20:23.958202 2023-03-20 17:30:02.416620
# 7       7  0.6877 2023-03-20 17:08:07.097007 2023-03-20 17:10:28.075328
# 2       2  0.6357 2023-03-20 16:33:33.545935 2023-03-20 16:39:11.539991
# 8       8  0.4767 2023-03-20 17:10:28.103540 2023-03-20 17:20:23.928365
# 5       5  0.3969 2023-03-20 16:59:07.587512 2023-03-20 17:03:54.487231
# 1       1  0.3707 2023-03-20 16:26:34.364313 2023-03-20 16:33:33.516817
# 6       6  0.2120 2023-03-20 17:03:54.528334 2023-03-20 17:08:07.070446
# 0       0  0.1000 2023-03-20 16:17:57.490513 2023-03-20 16:26:34.319521
#
#                 duration params_activation  params_batch_size  \
# 3 0 days 00:10:47.815773               ELU                 86
# 4 0 days 00:09:08.147370              ReLU                201
# 9 0 days 00:09:38.458418              ReLU                 68
# 7 0 days 00:02:20.978321              ReLU                206
# 2 0 days 00:05:37.994056               ELU                254
# 8 0 days 00:09:55.824825               ELU                170
# 5 0 days 00:04:46.899719               ELU                 66
# 1 0 days 00:06:59.152504              ReLU                242
# 6 0 days 00:04:12.542112              ReLU                104
# 0 0 days 00:08:36.829008               ELU                164
#
#    params_fc_units  params_lr  params_num_epoch  params_num_layer  \
# 3             3241   0.001830                45                 6
# 4             1496   0.004220                49                 6
# 9             2791   0.004507                39                 7
# 7             1538   0.002896                12                 7
# 2             2755   0.000120                27                 5
# 8             2684   0.000348                47                 7
# 5             3140   0.000116                19                 6
# 1             2101   0.000353                37                 6
# 6             1808   0.000209                21                 6
# 0             2091   0.004586                41                 7
#
#   params_optimizer  params_weight_decay     state
# 3      MomentumSGD         1.461612e-06  COMPLETE
# 4             Adam         6.939160e-04  COMPLETE
# 9      MomentumSGD         1.294841e-08  COMPLETE
# 7             Adam         1.529459e-06  COMPLETE
# 2             Adam         1.874462e-08  COMPLETE
# 8      MomentumSGD         1.215698e-10  COMPLETE
# 5      MomentumSGD         1.053212e-07  COMPLETE
# 1      MomentumSGD         1.425571e-09  COMPLETE
# 6      MomentumSGD         5.581012e-04  COMPLETE
# 0             Adam         9.001636e-05  COMPLETE
