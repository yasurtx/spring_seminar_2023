# %% [markdown]
# <h3>課題1</h3>

# %%
a = ['m', 'c', 'i', 'e', 'p', 'r', 'e', 't', 'o', ' ', 'o', 'o', 'i', 's', 'g', 'o', 'p']
b = ['a', 'h', 'n', ' ', 'e', 'c', 'p', 'i', 'n', 'r', 'b', 't', 'c', '-', 'r', 'u', '!']

text = [x + y for x,y in zip(a,b)]

for ch in text:
        print(ch,end="")
# Out:
# machine perception robotics-group!

# %% [markdown]
# <h3>課題2</h3>

# %%
import numpy as np

math = np.array([40, 15, 72, 22, 43, 82, 75, 7, 34, 49, 95, 75, 85, 47, 63])

count = len([x for x in math if x >= 70])

print(count)
# Out:
# 6

# %% [markdown]
# <h3>課題3</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def softmax(x):
    exp_x = np.exp(x)
    return exp_x / np.sum(exp_x)


def tanh(x):
    return np.tanh(x)


x = np.arange(-5.0, 5.0, 0.1)
y_sigmoid = sigmoid(x)
y_softmax = softmax(x)
y_tanh = tanh(x)

fig,ax = plt.subplots()
plt.plot(x, y_sigmoid, label='sigmoid')
plt.plot(x, y_softmax, label='softmax')
plt.plot(x, y_tanh, label='tanh')
plt.ylim(-1.2, 1.2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sigmoid, Softmax, and Tanh Functions')
ax.grid(True)
plt.legend()
plt.show()
